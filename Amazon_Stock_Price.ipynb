# %% [markdown]
# <a href="https://colab.research.google.com/github/Eng-Zakaria/Amazon_Stock_Price/blob/main/Amazon_Stock_Price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -O Amazon_Stock_Price.zip "https://storage.googleapis.com/kaggle-data-sets/4916420/8278935/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20240501%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240501T121050Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=..."
# Out:
# --2024-05-01 12:14:57--  https://storage.googleapis.com/kaggle-data-sets/4916420/8278935/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20240501%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240501T121050Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.7.59, 172.217.12.27, 142.250.65.123, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.7.59|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 155886 (152K) [application/zip]
# Saving to: ‘Amazon_Stock_Price.zip’
#
# Amazon_Stock_Price. 100%[===================>] 152.23K  --.-KB/s    in 0.002s
#
# 2024-05-01 12:14:57 (81.0 MB/s) - ‘Amazon_Stock_Price.zip’ saved [155886/155886]

# %%
# !unzip Amazon_Stock_Price.zip
# Out:
# Archive:  Amazon_Stock_Price.zip
#   inflating: Amazon_Stock_Price.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10,6)
sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('Amazon_Stock_Price.csv')
df.head(5)
# Out:
#    Unnamed: 0        Date  Open  High   Low  Close     Volume
# 0           0  2000-01-03 4.075 4.478 3.952  4.469  322352000
# 1           1  2000-01-04 4.269 4.575 4.088  4.097  349748000
# 2           2  2000-01-05 3.525 3.756 3.400  3.487  769148000
# 3           3  2000-01-06 3.566 3.634 3.200  3.278  375040000
# 4           4  2000-01-07 3.350 3.525 3.309  3.478  210108000

# %%
df = pd.read_csv('Amazon_Stock_Price.csv',
                 index_col='Date',
                 parse_dates=True
                )

# %%
df.drop(columns=['Unnamed: 0'],axis=1,inplace=True)

# %%
df.head(10)
# Out:
#             Open  High   Low  Close     Volume
# Date
# 2000-01-03 4.075 4.478 3.952  4.469  322352000
# 2000-01-04 4.269 4.575 4.088  4.097  349748000
# 2000-01-05 3.525 3.756 3.400  3.487  769148000
# 2000-01-06 3.566 3.634 3.200  3.278  375040000
# 2000-01-07 3.350 3.525 3.309  3.478  210108000
# 2000-01-10 3.628 3.631 3.278  3.459  295158000
# 2000-01-11 3.344 3.500 3.250  3.338  210654000
# 2000-01-12 3.394 3.400 3.150  3.178  216090000
# 2000-01-13 3.247 3.359 3.156  3.297  208962000
# 2000-01-14 3.338 3.431 3.200  3.213  137072000

# %%
df.tail()
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2024-01-12 155.390 156.200 154.010 154.620  40460300
# 2024-01-16 153.530 154.990 152.150 153.160  41384600
# 2024-01-17 151.490 152.150 149.910 151.710  34953400
# 2024-01-18 152.770 153.780 151.820 153.500  37850200
# 2024-01-19 153.830 155.760 152.740 155.340  51033700

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6050 entries, 2000-01-03 to 2024-01-19
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    6050 non-null   float64
#  1   High    6050 non-null   float64
#  2   Low     6050 non-null   float64
#  3   Close   6050 non-null   float64
#  4   Volume  6050 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 283.6 KB

# %%
df.shape
# Out:
# (6050, 5)

# %%
df.plot(figsize=(16,8))
# Out:
# <Axes: xlabel='Date'>

# %%
df_plt = df[['Open','Close','High','Low']]

# %%
df_plt.plot(figsize = (12,6))
plt.title('Amazon Stock Prices')
# Out:
# Text(0.5, 1.0, 'Amazon Stock Prices')

# %%
df_plt = df_plt["2020":"2024"]
df_plt.plot(figsize=(12,6))
# Out:
# <Axes: xlabel='Date'>

# %%
train = df[:'2023'].iloc[:,1:2].values
test = df['2024':].iloc[:,1:2].values

# %%
# You can choose any price value i decided to choose high
df["High"][:'2023'].plot(figsize=(16,4),legend=True)
df["High"]['2024':].plot(figsize=(16,4),legend=True)
plt.title('Amazon stock price')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler(feature_range=(0,1))
train_scaled = scaler.fit_transform(train)

# %%
plt.plot(train_scaled)
plt.show()

# %%
train_scaled.shape
# Out:
# (6037, 1)

# %%
X_train = []
y_train = []
for i in range(60,6037):
    X_train.append(train_scaled[i-30:i,0])
    y_train.append(train_scaled[i,0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

# %%
regressor = Sequential()

regressor.add(LSTM(units=128, return_sequences=True, input_shape=(X_train.shape[1],1)))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units=64, return_sequences=True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units=32, return_sequences=True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units=16))
regressor.add(Dropout(0.2))
# The output layer
regressor.add(Dense(units=1))

# %%
regressor.compile(optimizer='adam', loss='mse')

# %%
regressor.fit(X_train,y_train,epochs=50,batch_size=32)
# Out:
# Epoch 1/50
# 187/187 [==============================] - 31s 124ms/step - loss: 0.0062
# Epoch 2/50
# 187/187 [==============================] - 22s 115ms/step - loss: 0.0029
# Epoch 3/50
# 187/187 [==============================] - 18s 95ms/step - loss: 0.0027
# Epoch 4/50
# 187/187 [==============================] - 17s 88ms/step - loss: 0.0023
# Epoch 5/50
# 187/187 [==============================] - 15s 80ms/step - loss: 0.0022
# Epoch 6/50
# 187/187 [==============================] - 15s 81ms/step - loss: 0.0020
# Epoch 7/50
# 187/187 [==============================] - 15s 80ms/step - loss: 0.0020
# Epoch 8/50
# 187/187 [==============================] - 17s 89ms/step - loss: 0.0019
# Epoch 9/50
# 187/187 [==============================] - 15s 80ms/step - loss: 0.0018
# Epoch 10/50
# 187/187 [==============================] - 16s 83ms/step - loss: 0.0021
# Epoch 11/50
# 187/187 [==============================] - 15s 81ms/step - loss: 0.0019
# Epoch 12/50
# ...

# %%
dataset_total = pd.concat((df["High"][:'2023'],df["High"]['2024':]),axis=0)
inputs = dataset_total[len(dataset_total)-len(test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)

# %%
inputs.shape
# Out:
# (73, 1)

# %%
X_test = []
for i in range(60,73):
    X_test.append(inputs[i-30:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)
# Out:
# 1/1 [==============================] - 3s 3s/step

# %%
def plot_predictions(test,predicted):
    plt.plot(test, color='red',label='Real Amazon Stock Price')
    plt.plot(predicted, color='blue',label='Predicted Amazon Stock Price')
    plt.title('Amazon Stock Price Prediction')
    plt.xlabel('Time')
    plt.ylabel('Amazon Stock Price')
    plt.legend()
    plt.show()

# %%
plot_predictions(test,predicted_stock_price)
